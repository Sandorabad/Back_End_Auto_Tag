# %%
#tipicas
import pandas as pd
import numpy as np

#para la creacion de carpetas
import os
import shutil

#para el test-train split
import splitfolders #(necesita pip install split-folders)

# %%
#importamos el df con las labels
path_csv = "/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/filtered_styles_full.csv"
df = pd.read_csv(path_csv)
list_id = list(df.id)

# %%
class_names_y1 = np.unique(df.masterCategory).tolist()
class_names_y1
# Out:
# ['Accessories', 'Apparel', 'Footwear', 'Personal Care']

# %%
class_names_y21 = np.unique(df[df['masterCategory'] == class_names_y1[0]].subCategory).tolist()
class_names_y22 = np.unique(df[df['masterCategory'] == class_names_y1[1]].subCategory).tolist()
class_names_y23 = np.unique(df[df['masterCategory'] == class_names_y1[2]].subCategory).tolist()
class_names_y24 = np.unique(df[df['masterCategory'] == class_names_y1[3]].subCategory).tolist()

# %%
for i in class_names_y1:
    os.makedirs(os.path.join("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2",i))

# %%
for i in class_names_y21:
    os.makedirs(os.path.join(f'/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/{class_names_y1[0]}/',i))

for i in class_names_y22:
    os.makedirs(os.path.join(f'/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/{class_names_y1[1]}/',i))
    
for i in class_names_y23:
    os.makedirs(os.path.join(f'/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/{class_names_y1[2]}/',i))
    
for i in class_names_y24:
    os.makedirs(os.path.join(f'/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/{class_names_y1[3]}/',i))

# %%
for i in class_names_y21:     # I ->  class label names
    for c in list(df[df['subCategory']== i]['name']):    # c  ->  individual image 
        try:
            get_image = os.path.join("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_1/Accessories",c)
            if not os.path.exists("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Accessories/"+i+"/"+c):
                move = shutil.copy(get_image,"/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Accessories/"+i)
        except:
            print("An exception occurred")
# Out:
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred

# %%
for i in class_names_y22:     # I ->  class label names
    for c in list(df[df['subCategory']== i]['name']):    # c  ->  individual image 
        try:
            get_image = os.path.join("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_1/Apparel",c)
            if not os.path.exists("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Apparel/"+i+"/"+c):
                move = shutil.copy(get_image,"/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Apparel/"+i)
        except:
            print("An exception occurred")
# Out:
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
# ...

# %%
for i in class_names_y23:     # I ->  class label names
    for c in list(df[df['subCategory']== i]['name']):    # c  ->  individual image 
        try:
            get_image = os.path.join("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_1/Footwear",c)
            if not os.path.exists("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Footwear/"+i+"/"+c):
                move = shutil.copy(get_image,"/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Footwear/"+i)
        except:
            print("An exception occurred")

# %%
for i in class_names_y24:     # I ->  class label names
    for c in list(df[df['subCategory']== i]['name']):    # c  ->  individual image 
        try:
            get_image = os.path.join("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_1/Personal Care",c)
            if not os.path.exists("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Personal Care/"+i+"/"+c):
                move = shutil.copy(get_image,"/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/Personal Care/"+i)
        except:
            print("An exception occurred")
# Out:
# An exception occurred

# %%
# for i in class_names_y24:     # I ->  class label names
#     for c in list(df[df['subCategory']== i]['name']):    # c  ->  individual image 
#     # Creating path to the image
#         get_image = os.path.join("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_small",c)
#         if not os.path.exists("/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_small_sort2/Personal Care/"+i+"/"+c):
#             move = shutil.copy(get_image,"/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_small_sort2/Personal Care/"+i)

# %%
input_folder = "/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/data_sort_2/"
output_folder = "/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/split_2/"
for i in class_names_y1:
    input_folder2 = input_folder + i
    output_folder2 = output_folder+i

    splitfolders.ratio(input_folder2, output=output_folder2,
                        seed=42,
                        ratio=(.7, .2, .1), #usamos 70% train, 20% val, 10% test 
                        group_prefix=None)

# %%
path_csv = "/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/filtered_styles_full.csv"
df = pd.read_csv(path_csv)

# %%
labels1 = ['Accessories', 'Apparel', 'Footwear', 'Personal Care']
# np.unique(df[df['masterCategory'] == labels1[3]].subCategory).tolist()

# %%
labels1 = ['Accessories', 'Apparel', 'Footwear', 'Personal Care']

#ACCESORIES
labels2 = ['Accessories', 'Bags', 'Belts', 'Cufflinks', 'Eyewear', 'Gloves', 'Headwear', 'Jewellery', 'Mufflers',
            'Perfumes', 'Scarves', 'Shoe Accessories', 'Socks', 'Sports Accessories', 'Stoles', 'Ties', 'Umbrellas',
            'Wallets', 'Watches', 'Water Bottle']

#APPAREL
labels3 = ['Apparel Set', 'Bottomwear', 'Dress', 'Innerwear', 'Loungewear and Nightwear', 'Saree', 'Socks', 'Topwear']

#FOOTWEAR
labels4 = ['Flip Flops', 'Sandal', 'Shoes']

#PERSONAL CARE
labels5 = ['Bath and Body', 'Beauty Accessories', 'Eyes', 'Fragrance', 'Hair', 'Lips', 'Makeup', 'Nails', 'Perfumes',
                'Skin', 'Skin Care']

# %%
cat_dict = {"Master" : labels1,
                "Accesories" : labels2,
                "Apparel" : labels3,
                "Footwear" : labels4,
                "Personal Care" : labels5}

# %%
cat_dict['Apparel']
# Out:
# ['Apparel Set',
#  'Bottomwear',
#  'Dress',
#  'Innerwear',
#  'Loungewear and Nightwear',
#  'Saree',
#  'Socks',
#  'Topwear']

# %%
import io
from PIL import Image

img_path = '/home/vvdiaz1/code/vvdiaz1/automatic_tagging/raw_data/split2_full/Footwear/test/Sandal/2802.jpg'

with open(img_path, 'rb') as f:
    image = Image.open(f)
    image_bytes = io.BytesIO()
    image.save(image_bytes, format='JPEG')
    image_bytes.seek(0)

# %%
type(image_bytes)
# Out:
# _io.BytesIO

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile
